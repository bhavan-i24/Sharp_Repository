# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

df_prints = spark.table("toner_regression_features")

window_pc = Window.partitionBy("deviceId", "color").orderBy("timestamp")
df_with_prints = (
    df_prints
    .withColumn(
        "cumulative_print_count",
        F.sum("delta_print_count").over(window_pc)
    )
)

df_math_prints = df_with_prints.select(
    "deviceId",
    "color",
    "cumulative_print_count",
    F.col("toner_pct_remaining").alias("typical")
)

df_stats_prints = (
    df_math_prints
    .groupBy("deviceId", "color")
    .agg(
        F.count("*").alias("n"),
        F.sum("cumulative_print_count").alias("sum_x"),
        F.sum("typical").alias("sum_y"),
        F.sum(F.col("cumulative_print_count") * F.col("typical")).alias("sum_xy"),
        F.sum(F.col("cumulative_print_count") ** 2).alias("sum_x2")
    )
)

df_regression_prints= (
    df_stats_prints
    .withColumn(
        "m",
        (
            F.col("n") * F.col("sum_xy") -
            F.col("sum_x") * F.col("sum_y")
        ) /
        (
            F.col("n") * F.col("sum_x2") -
            F.col("sum_x") ** 2
        )
    )
    .withColumn(
        "c",
        (F.col("sum_y") - F.col("m") * F.col("sum_x")) / F.col("n")
    )
)
df_prediction_prints = (
    df_regression_prints
    .withColumn(
        "predicted_print_count",
        -F.col("c") / F.col("m")
    )
    .filter(
        (F.col("m") < 0) & 
        (F.col("predicted_print_count") > 0)
    )
)
df_prediction_prints.select(
    "deviceId",
    "color",
    "predicted_print_count"
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deviceId</th><th>color</th><th>predicted_print_count</th></tr></thead><tbody><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>black</td><td>15355.558776606418</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>cyan</td><td>18326.339534580333</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>magenta</td><td>20830.184457505555</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>yellow</td><td>21867.754384084627</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>black</td><td>29210.774879009048</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>cyan</td><td>15174.796875000002</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>magenta</td><td>9601.023622047243</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>yellow</td><td>9231.731343283584</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>black</td><td>22803.515427375347</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>cyan</td><td>35255.33241111863</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>magenta</td><td>48425.41662394174</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>yellow</td><td>107592.91722852817</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>black</td><td>14170.303581657507</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>cyan</td><td>24420.77752305556</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>magenta</td><td>30112.00707395545</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>yellow</td><td>30363.694313096097</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=MzMwMDY4MDgwMA==</td><td>cyan</td><td>4237.9266415250295</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=MzMwMDY4MDgwMA==</td><td>magenta</td><td>3197.563901880309</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=MzMwMDY4MDgwMA==</td><td>yellow</td><td>1938.1138957389458</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>black</td><td>576192.7884358693</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>cyan</td><td>13736.534792948276</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>magenta</td><td>11539.881412690827</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>yellow</td><td>10060.860925302448</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMTE1MjgwMA==</td><td>black</td><td>55999.89123317381</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMTE1MjgwMA==</td><td>cyan</td><td>11761.881544263153</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMTE1MjgwMA==</td><td>magenta</td><td>11673.393188418111</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMTE1MjgwMA==</td><td>yellow</td><td>9410.879131402542</td></tr></tbody></table></div>

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

df1 = spark.table("toner_regression_features")

window_pc = Window.partitionBy("deviceId", "color").orderBy("timestamp")

df_pc = (
    df1
    .withColumn(
        "cumulative_print_count",
        F.sum("delta_print_count").over(window_pc)
    )
)

from pyspark.ml.feature import VectorAssembler

df_ml_base = df_pc.select(
    "deviceId",
    "color",
    F.col("toner_pct_remaining").alias("label"),
    "cumulative_print_count"
)

assembler1 = VectorAssembler(
    inputCols=["cumulative_print_count"],
    outputCol="features"
)

df_ml1 = assembler1.transform(df_ml_base).select(
    "deviceId",
    "color",
    "label",
    "features"
)

from pyspark.ml.regression import LinearRegression

results = []

pairs = df_ml1.select("deviceId", "color").distinct().collect()

for r in pairs:
    device = r["deviceId"]
    color = r["color"]

    df_group = df_ml1.filter(
        (F.col("deviceId") == device) &
        (F.col("color") == color)
    )

    # Need at least 2 points
    if df_group.count() < 2:
        continue

    lr = LinearRegression(
        featuresCol="features",
        labelCol="label",
        fitIntercept=True
    )

    model = lr.fit(df_group)

    m = model.coefficients[0]
    c = model.intercept

    # Valid depletion model
    if m >= 0:
        continue

    predicted_print_count = -c / m

    results.append(
        (device, color, m, c, predicted_print_count)
    )

from pyspark.sql.types import StructType, StructField, StringType, DoubleType
schema1= StructType([
    StructField("deviceId", StringType(), True),
    StructField("color", StringType(), True),
    StructField("slope_m", DoubleType(), True),
    StructField("intercept_c", DoubleType(), True),
    StructField("predicted_print_count", DoubleType(), True)
])

df_predictions = spark.createDataFrame(results, schema1)

df_predictions.filter(
    F.col("predicted_print_count") > 0
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deviceId</th><th>color</th><th>slope_m</th><th>intercept_c</th><th>predicted_print_count</th></tr></thead><tbody><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>black</td><td>-0.006273859763255597</td><td>96.3386223508573</td><td>15355.55877660641</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>cyan</td><td>-0.0050220344386555</td><td>92.03550827715637</td><td>18326.33953458036</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>magenta</td><td>-0.0044163414500378384</td><td>91.99320703161555</td><td>20830.184457505515</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5MzcwMA==</td><td>yellow</td><td>-0.004124745653344152</td><td>90.19892484415047</td><td>21867.754384084597</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>black</td><td>-0.0032572852099922683</td><td>95.1478249858095</td><td>29210.77487900894</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>cyan</td><td>-0.005027889072197361</td><td>76.29719538062692</td><td>15174.796874999953</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>magenta</td><td>-0.007788862539864135</td><td>74.7810532341156</td><td>9601.023622047393</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDY5OTYwMA==</td><td>yellow</td><td>-0.008049981977652445</td><td>74.31527093596063</td><td>9231.731343283407</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>black</td><td>-0.0021268613537503895</td><td>48.49991569213579</td><td>22803.515427375518</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>cyan</td><td>-0.0019167346261895792</td><td>67.57511639021479</td><td>35255.332411118616</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>magenta</td><td>-9.908127969007858E-4</td><td>47.980522486253534</td><td>48425.416623941754</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYwOTcwMA==</td><td>yellow</td><td>-4.2846562704713947E-4</td><td>46.099866746152415</td><td>107592.91722852844</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>black</td><td>-0.004539366114541186</td><td>64.32419591133763</td><td>14170.303581657494</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>cyan</td><td>-0.0035950789599389394</td><td>87.79462345848674</td><td>24420.77752305554</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>magenta</td><td>-0.0029570814972534687</td><td>89.04365896355921</td><td>30112.007073955447</td></tr><tr><td>mn=QlA1MEM1NQ==:sn=NDMwMDYxNzcwMA==</td><td>yellow</td><td>-0.0030137608003869797</td><td>91.50891167574204</td><td>30363.694313096086</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=MzMwMDY4MDgwMA==</td><td>cyan</td><td>-0.0037357792584255325</td><td>15.831958446138165</td><td>4237.926641525025</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=MzMwMDY4MDgwMA==</td><td>magenta</td><td>-0.004021845488504329</td><td>12.86010795298161</td><td>3197.5639018803067</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=MzMwMDY4MDgwMA==</td><td>yellow</td><td>-0.004461069449106406</td><td>8.646060689169609</td><td>1938.1138957389455</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>black</td><td>-8.22844379285099E-5</td><td>47.41169973490682</td><td>576192.7884358753</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>cyan</td><td>-0.004808208966972269</td><td>66.04812976658047</td><td>13736.534792948278</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>magenta</td><td>-0.00544597654624574</td><td>62.845923519971386</td><td>11539.881412690824</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMDcxOTcwMA==</td><td>yellow</td><td>-0.005843634670270063</td><td>58.79199571586272</td><td>10060.860925302446</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMTE1MjgwMA==</td><td>black</td><td>-0.0013247602864415113</td><td>74.18643195075283</td><td>55999.891233173825</td></tr><tr><td>mn=QlA1MEM2NQ==:sn=NDMwMTE1MjgwMA==</td><td>cyan</td><td>-0.005967595353408254</td><td>70.19014965088346</td><td>11761.881544263213</td></tr><tr><td> ...
