# %%
df_raw = (
    spark.read
         .option("recursiveFileLookup", "true")
         .option("multiLine", "true")
         .json("/Volumes/workspace/default/json_raw_volume/IOT Device Status Messages/")
)

df_raw.printSchema()   # MUST show Body
# Out:
# root
#  |-- Body: struct (nullable = true)
#  |    |-- code: string (nullable = true)
#  |    |-- mnsn: string (nullable = true)
#  |    |-- scheduleName: string (nullable = true)
#  |    |-- smsProperties: struct (nullable = true)
#  |    |    |-- device: struct (nullable = true)
#  |    |    |    |-- address: string (nullable = true)
#  |    |    |    |-- disposalMarkerList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |-- capacity: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |    |-- typical: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- familyName: string (nullable = true)
#  |    |    |    |-- friendlyName: string (nullable = true)
#  |    |    |    |-- inTrayList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |-- capacity: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |    |-- typical: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- inserter: string (nullable = true)
#  |    |    |    |    |    |-- manual: string (nullable = true)
#  |    |    |    |    |    |-- mediaDimFeed: string (nullable = true)
#  |    |    |    |    |    |-- mediaDimXFeed: string (nullable = true)
#  |    |    |    |    |    |-- mediaName: string (nullable = true)
#  |    |    |    |    |    |-- mediaSize: string (nullable = true)
#  |    |    |    |    |    |-- mediaSizeHeight: string (nullable = true)
#  |    |    |    |    |    |-- mediaSizeName: string (nullable = true)
#  |    |    |    |    |    |-- mediaSizeUnit: string (nullable = true)
#  |    |    |    |    |    |-- mediaSizeWidth: string (nullable = true)
#  |    |    |    |    |    |-- mediaType: string (nullable = true)
#  |    |    |    |    |    |-- modelName: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- virtual: string (nullable = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- address: string (nullable = true)
#  |    |    |    |-- markerList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |-- capacity: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |    |-- typical: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- modelName: string (nullable = true)
#  |    |    |    |-- outTrayList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |-- capacity: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |    |-- typical: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |-- deliveryOrientation: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- modelName: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- stackingOrder: string (nullable = true)
#  |    |    |    |-- serialId: string (nullable = true)
#  |    |    |    |-- statusRawValue: string (nullable = true)
#  |    |    |    |-- suppliesCounter: struct (nullable = true)
#  |    |    |    |    |-- TYPE: struct (nullable = true)
#  |    |    |    |    |    |-- toner: struct (nullable = true)
#  |    |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- end: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- black: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- cyan: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- magenta: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- yellow: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- inserted: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- black: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- cyan: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- magenta: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- yellow: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- nearNearEnd: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- black: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- cyan: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- magenta: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- yellow: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- end: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- black: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- cyan: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- magenta: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- yellow: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- inserted: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- black: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- cyan: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- magenta: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- yellow: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- nearNearEnd: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- black: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- cyan: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- magenta: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- yellow: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |-- tonerConsumption: struct (nullable = true)
#  |    |    |    |    |    |    |-- COLORTYPE: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- color: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fullcolor: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- singlecolor: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- threecolor: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- twocolor: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |    |    |    |-- monochrome: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |-- interface: struct (nullable = true)
#  |    |    |    |-- ethernetList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- address: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- ipList: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- address: string (nullable = true)
#  |    |    |    |    |    |-- defaultRoute: string (nullable = true)
#  |    |    |    |    |    |-- ethernetId: string (nullable = true)
#  |    |    |    |    |    |-- subnetMask: string (nullable = true)
#  |    |-- timestamp: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- EnqueuedTimeUtc: string (nullable = true)
#  |-- Properties: struct (nullable = true)
#  |    |-- appTopic: string (nullable = true)
#  |    |-- customerId: string (nullable = true)
#  |    |-- dealerId: string (nullable = true)
#  |    |-- relatedGroupId: string (nullable = true)
#  |-- SystemProperties: struct (nullable = true)
#  |    |-- connectionAuthMethod: string (nullable = true)
#  |    |-- connectionDeviceGenerationId: string (nullable = true)
#  |    |-- connectionDeviceId: string (nullable = true)
#  |    |-- contentEncoding: string (nullable = true)
#  |    |-- contentType: string (nullable = true)
#  |    |-- enqueuedTime: string (nullable = true)

# %%
df_raw.columns
# Out:
# ['Body', 'EnqueuedTimeUtc', 'Properties', 'SystemProperties']

# %%
from pyspark.sql.functions import col

df_device_latest = df_raw.select(
    # Primary keys
    col("Body.mnsn").alias("_id"),
    col("Body.timestamp").alias("createTimestamp"),

    # Metadata
    col("Body.type").alias("type"),
    col("Properties.relatedGroupId").alias("relatedGroupId"),
    col("Properties.customerId").alias("customerId"),
    col("Properties.dealerId").alias("dealerId"),

    # Device General
    col("Body.smsProperties.device.familyName").alias("familyName"),
    col("Body.smsProperties.device.friendlyName").alias("friendlyName"),
    col("Body.smsProperties.device.modelName").alias("modelName"),
    col("Body.smsProperties.device.serialId").alias("serialNumber"),

    # Printer device
    col("Body.smsProperties.device.statusRawValue").alias("communicationStatus"),
    col("Body.smsProperties.device.location.address").alias("location"),

    # Network
    #col("Body.device.interface").alias("interface")
    
)

# %%
df_device_latest.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>createTimestamp</th><th>type</th><th>relatedGroupId</th><th>customerId</th><th>dealerId</th><th>familyName</th><th>friendlyName</th><th>modelName</th><th>serialNumber</th><th>communicationStatus</th><th>location</th></tr></thead><tbody><tr><td>mn=QlA1MEMyNg==:sn=MjUxMjA1NTAwMA==</td><td>1765690085229</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-155</td><td></td><td>SHARP BP-50C26</td><td>2512055000</td><td>3308192</td><td>Near to Device Managemet Team</td></tr><tr><td>mn=QlA1MEMyNg==:sn=MjUxMjA1NTAwMA==</td><td>1765690085343</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-155</td><td></td><td>SHARP BP-50C26</td><td>2512055000</td><td>3308192</td><td>Near to Device Managemet Team</td></tr><tr><td>mn=TVgzNTYwTg==:sn=NzUwNjkzMjYwMA==</td><td>1765690085763</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-112</td><td></td><td>SHARP MX-3560N</td><td>7506932600</td><td>2300000</td><td></td></tr><tr><td>mn=TVgzNTYwTg==:sn=NzUwNjkzMjYwMA==</td><td>1765690085926</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-112</td><td></td><td>SHARP MX-3560N</td><td>7506932600</td><td>2300000</td><td></td></tr><tr><td>mn=QlA1MEMyNg==:sn=MjUxMjA1NTAwMA==</td><td>1765690086254</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-155</td><td></td><td>SHARP BP-50C26</td><td>2512055000</td><td>3308192</td><td>Near to Device Managemet Team</td></tr><tr><td>mn=TVgzNTYwTg==:sn=NzUwNjkzMjYwMA==</td><td>1765690086439</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-112</td><td></td><td>SHARP MX-3560N</td><td>7506932600</td><td>2300000</td><td></td></tr><tr><td>mn=QlA0MUMzNg==:sn=NDQxMjgwMjI1NQ==</td><td>1765690086775</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-193</td><td></td><td>SHARP BP-41C36</td><td>4412802255</td><td>5302048</td><td></td></tr><tr><td>mn=QlA0MUMzNg==:sn=NDQxMjgwMjI1NQ==</td><td>1765690087060</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-193</td><td></td><td>SHARP BP-41C36</td><td>4412802255</td><td>5302048</td><td></td></tr><tr><td>mn=QlA0MUMzNg==:sn=NDQxMjgwMjI1NQ==</td><td>1765690087405</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-193</td><td></td><td>SHARP BP-41C36</td><td>4412802255</td><td>5302048</td><td></td></tr><tr><td>mn=QlA1MEMyNg==:sn=MzMzMzMzMzMyMw==</td><td>1765690088359</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-155</td><td></td><td>SHARP BP-50C26</td><td>3333333323</td><td>3108192</td><td>GIRISH</td></tr><tr><td>mn=QlA1MEMyNg==:sn=MzMzMzMzMzMyMw==</td><td>1765690089473</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-155</td><td></td><td>SHARP BP-50C26</td><td>3333333323</td><td>3108192</td><td>GIRISH</td></tr><tr><td>mn=QlA1MEMyNg==:sn=MzMzMzMzMzMyMw==</td><td>1765690089630</td><td>smsProps</td><td>6de069dd-89d2-43b5-bc64-15ffbba5ccd6</td><td>b8bf935d-026c-426a-b9f2-ef97d01bf973</td><td>281083</td><td>SHARP-155</td><td></td><td>SHARP BP-50C26</td><td>3333333323</td><td>3108192</td><td>GIRISH</td></tr><tr><td>mn=QlA1MEMyNg==:sn=MjUxMjA1N ...

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, desc

window_spec = Window.partitionBy("_id").orderBy(desc("createTimestamp"))

df_dedup = (
    df_device_latest
    .withColumn("rn", row_number().over(window_spec))
    .filter(col("rn") == 1)
    .drop("rn")
)

# %%
from delta.tables import DeltaTable

delta_tbl = DeltaTable.forName(spark, "device_latest")

delta_tbl.alias("t").merge(
    df_dedup.alias("s"),
    "t._id = s._id"
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7889749336392073>, line 10
#       1 from delta.tables import DeltaTable
#       3 delta_tbl = DeltaTable.forName(spark, "device_latest")
#       5 delta_tbl.alias("t").merge(
#       6     df_dedup.alias("s"),
#       7     "t._id = s._id"
#       8 ).whenMatchedUpdateAll() \
#       9  .whenNotMatchedInsertAll() \
# ---> 10  .execute()
#
# File /databricks/python/lib/python3.12/site-packages/delta/connect/tables.py:609, in DeltaMergeBuilder.execute(self)
#     599 plan = MergeIntoTable(
#     600     self._target,
#     601     self._source,
#    (...)
#     606     self._with_schema_evolution
#     607 )
#     608 df = DataFrame(plan, session=self._spark)
# --> 609 return self._spark.createDataFrame(df.toPandas())
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1903, in DataFrame.toPandas(self)
#    1901 def toPandas(self) -> "PandasDataFrameLike":
#    1902     query = self._plan.to_proto(self._session.client)
# -> 1903     pdf, ei = self._session.client.to_pandas(query, self._plan.observations)
#    1904     self._execution_info = ei
#    1905     return pdf
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1344, in SparkConnectClient.to_pandas(self, plan, observations)
#    1340 (self_destruct_conf,) = self.get_config_with_defaults(
#    1341     ("spark.sql.execution.arrow.pyspark.selfDestruct.enabled", "false"),
#    1342 )
#    1343 self_destruct = cast(str, self_destruct_conf).lower() == "true"
# -> 1344 table, schema, metrics, observed_metrics, _ = self._execute_and_fetch(
#    1345     req, observations, self_destruct=self_destruct
#    1346 )
#    1347 assert table is not None
#    1348 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2059, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    2056 properties: Dict[str, Any] = {}
#    2058 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 2059     for response in self._execute_and_fetch_as_iterator(
#    2060         req, observations, extra_request_metadata or [], progress=progress
#    2061     ):
#    2062         if isinstance(response, StructType):
#    2063             schema = response
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2035, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    2033     raise kb
#    2034 except Exception as error:
# -> 2035     self._handle_error(error)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2355, in SparkConnectClient._handle_error(self, error)
#    2353     self.thread_local.inside_error_handling = True
#    2354     if isinstance(error, grpc.RpcError):
# -> 2355         self._handle_rpc_error(error)
#    2356     raise error
#    2357 finally:
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2433, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2429             logger.debug(f"Received ErrorInfo: {info}")
#    2431             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2433             raise convert_exception(
#    2434                 info,
#    2435                 status.message,
#    2436                 self._fetch_enriched_error(info),
#    2437                 self._display_server_stack_trace(),
#    2438                 status_code,
#    2439             ) from None
#    2441     raise SparkConnectGrpcException(
#    2442         message=status.message,
#    2443         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2444         grpc_status_code=status_code,
#    2445     ) from None
#    2446 else:
#
# AnalysisException: [DELTA_MISSING_DELTA_TABLE] `device_latest` is not a Delta table.
#
# JVM stacktrace:
# com.databricks.sql.transaction.tahoe.DeltaAnalysisException
# 	at com.databricks.sql.transaction.tahoe.DeltaErrorsBase.notADeltaTableException(DeltaErrors.scala:706)
# 	at com.databricks.sql.transaction.tahoe.DeltaErrorsBase.notADeltaTableException$(DeltaErrors.scala:705)
# 	at com.databricks.sql.transaction.tahoe.DeltaErrors$.notADeltaTableException(DeltaErrors.scala:4111)
# 	at io.delta.tables.DeltaTable$.getDeltaTableFromSessionCatalog(DeltaTable.scala:1826)
# 	at io.delta.tables.DeltaTable$.forName(DeltaTable.scala:1846)
# 	at io.delta.connect.DeltaPlannerBase.transformDeltaTableWithoutTracker(DeltaPlannerBase.scala:47)
# 	at io.delta.connect.DeltaPlannerBase.transformDeltaTableWithoutTracker$(DeltaPlannerBase.scala:40)
# 	at io.delta.connect.DeltaRelationPlugin.transformDeltaTableWithoutTracker(DeltaRelationPlugin.scala:47)
# 	at io.delta.connect.DeltaRelationPlugin.transformScan(DeltaRelationPlugin.scala:92)
# 	at io.delta.connect.DeltaRelationPlugin.transform(DeltaRelationPlugin.scala:67)
# 	at io.delta.connect.DeltaRelationPlugin.transform(DeltaRelationPlugin.scala:56)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelationPlugin$1(SparkConnectPlanner.scala:358)
# 	at scala.collection.Iterator$$anon$9.next(Iterator.scala:584)
# 	at scala.collection.IterableOnceOps.find(IterableOnce.scala:677)
# 	at scala.collection.IterableOnceOps.find$(IterableOnce.scala:674)
# 	at scala.collection.AbstractIterable.find(Iterable.scala:935)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelationPlugin(SparkConnectPlanner.scala:361)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:326)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$8(SessionHolder.scala:739)
# 	at org.apache.spark.sql.connect.service.SessionHolder.measureSubtreeRelationNodes(SessionHolder.scala:755)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$6(SessionHolder.scala:738)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:736)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:212)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:198)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformSubqueryAlias(SparkConnectPlanner.scala:469)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:239)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$8(SessionHolder.scala:739)
# 	at org.apache.spark.sql.connect.service.SessionHolder.measureSubtreeRelationNodes(SessionHolder.scala:755)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$6(SessionHolder.scala:738)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:736)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:212)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:198)
# 	at io.delta.connect.DeltaRelationPlugin.transformMergeIntoTable(DeltaRelationPlugin.scala:177)
# 	at io.delta.connect.DeltaRelationPlugin.transform(DeltaRelationPlugin.scala:83)
# 	at io.delta.connect.DeltaRelationPlugin.transform(DeltaRelationPlugin.scala:56)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelationPlugin$1(SparkConnectPlanner.scala:358)
# 	at scala.collection.Iterator$$anon$9.next(Iterator.scala:584)
# 	at scala.collection.IterableOnceOps.find(IterableOnce.scala:677)
# 	at scala.collection.IterableOnceOps.find$(IterableOnce.scala:674)
# 	at scala.collection.AbstractIterable.find(Iterable.scala:935)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelationPlugin(SparkConnectPlanner.scala:361)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:326)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$8(SessionHolder.scala:739)
# 	at org.apache.spark.sql.connect.service.SessionHolder.measureSubtreeRelationNodes(SessionHolder.scala:755)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$6(SessionHolder.scala:738)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:736)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:212)
# 	at org.apache.spark.sql.connect.execution.SparkConnectPlanExecution.handlePlan(SparkConnectPlanExecution.scala:94)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handlePlan(ExecuteThreadRunner.scala:376)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:282)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:238)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:532)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:532)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:531)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:238)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:141)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:43)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:40)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:53)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:139)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:586)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
# 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
# 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:109)
# 	at scala.util.Using$.resource(Using.scala:296)
# 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:108)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:586)

# %%
df_dedup.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("device_latest")

# %%
spark.sql("DESCRIBE DETAIL device_latest").show(truncate=False)
# Out:
# +------+------------------------------------+-------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                           |description|location|createdAt              |lastModified       |partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties                           |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+-------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |b64544a5-2a70-40e0-a405-7a9be0dc8102|workspace.default.device_latest|NULL       |        |2025-12-22 05:40:01.482|2025-12-22 05:40:05|[]              |[]               |1       |4086       |{delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+-------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+

# %%
from delta.tables import DeltaTable

delta_tbl = DeltaTable.forName(spark, "device_latest")

delta_tbl.alias("t").merge(
    df_dedup.alias("s"),
    "t._id = s._id"
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
from delta.tables import DeltaTable

delta_tbl = DeltaTable.forName(spark, "device_latest")

delta_tbl.alias("t").merge(
    df_dedup.alias("s"),
    "t._id = s._id"
).whenMatchedUpdate(
    condition="s.createTimestamp > t.createTimestamp",
    set={col: f"s.{col}" for col in df_dedup.columns}
).whenNotMatchedInsertAll() \
 .execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
# %sql
SELECT _id, COUNT(*)
FROM device_latest
GROUP BY _id
HAVING COUNT(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>COUNT(*)</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT _id, MAX(createTimestamp)
FROM device_latest
GROUP BY _id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>MAX(createTimestamp)</th></tr></thead><tbody><tr><td>mn=QlA0MUMzNg==:sn=NDQxMjgwMjI1NQ==</td><td>1765765685979</td></tr><tr><td>mn=QlA1MEMyNg==:sn=MjUxMjA1NTAwMA==</td><td>1765765685118</td></tr><tr><td>mn=QlA1MEMyNg==:sn=MzMzMzMzMzMyMw==</td><td>1765765686727</td></tr><tr><td>mn=TVg1MDcwTg==:sn=STU0NjQz</td><td>1765746156156</td></tr><tr><td>mn=TVgzNTYwTg==:sn=NzUwNjkzMjYwMA==</td><td>1765765685294</td></tr></tbody></table></div>
